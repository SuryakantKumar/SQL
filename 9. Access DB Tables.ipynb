# %% [markdown]
# ## Access DB Tables
#
# * Get all the tables that are available in the Database

# %%
# %load_ext sql

# %%
# %env DATABASE_URL=postgresql://suryakantkumar:None@localhost:5432/suryakantkumar
# Out:
# env: DATABASE_URL=postgresql://suryakantkumar:None@localhost:5432/suryakantkumar

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     information_schema.tables
# WHERE
#     table_catalog = 'suryakantkumar'
#     AND
#     table_schema = 'public'
# LIMIT
#     10
# Out:
# 10 rows affected.
# [('suryakantkumar', 'public', 'users_range_part_201601', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'users_range_part_201602', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'users_range_part_201603', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'users_range_part_201604', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'users_range_part_201605', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'courses', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'users_range_part_201606', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'user_logins', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'users_range_part_201607', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('suryakantkumar', 'public', 'users_range_part_201608', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]
